# %% [markdown]
# ## Notebook Objectives

# %% [markdown]
# The objective of this notebook is to create a function that creates a square area based upon a users lat/long coordinates and the desired size (in miles) of the area.

# %%
import pandas as pd

# %%
# Import cleaned csv files
df_rest = pd.read_csv("CSVs/Rest_Stop_API.csv")
df_walmart = pd.read_csv("CSVs/Walmart_API.csv")
df_weigh = pd.read_csv("CSVs/Weigh_Station_API.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   Longitude   Latitude State Roadway Direction  \
# 0           0 -147.814902  61.800549    AK    AK-1     EB/WB
# 1           1  -87.418500  30.575840    AL    I-10        WB
# 2           2  -88.393032  30.477238    AL    I-10        EB
# 3           3  -85.369424  33.667729    AL    I-20        WB
# 4           4  -86.309572  33.850692    AL    I-59        NB
#
#                                          Name Mile Marker  Restrooms  \
# 0  MATANUSKA GLACIER STATE REC PARK REST AREA       MM101       True
# 1               BALDWIN COUNTY WELCOME CENTER      MM65.8       True
# 2                    GRAND BAY WELCOME CENTER      MM0.45       True
# 3                     CLEBURNE WELCOME CENTER       MM213       True
# 4                   ST CLAIR COUNTY REST AREA       MM164       True
#
#    Restrooms(Vault Toilet)  Restrooms(Portapotties)  Picnic Tables  \
# 0                    False                    False           True
# 1                    False                    False           True
# 2                    False                    False           True
# 3                    False                    False           True
# 4                    False                    False           True
#
#    Vending Machines  Pet Walking Area  Handicapped Facilities  RV Dump  \
# 0             False              True                    True    False
# 1              True              True                    True    False
# 2              True              True                    True     True
# 3              True              True                    True    False
# 4              True              True                    True     True
#
#    Restaurant    Gas  Scenic View
# 0       False  False         True
# 1       False  False        False
# 2       False  False        False
# 3       False  False        False
# 4       False  False        False

# %%
def location_finder(df, latitude, longitude, distance):
    """
    Returns places of interest within a designated area for a users specific geographic coordinates.
    
    Parameters:
        df (Pandas DataFrame): DataFrame containing places of interest and their corresponding lat/long coordinates
        latitude (Float value): Users designated latitude
        longitude (Float value): Users designated longitude
        distance (Int): Value that determines the search area size for designated place of interest
        
    Returns:
        df (Pandas DataFrame): DataFrame containing only the places of interest that are within the user's designated search area
    
    
    """
    
    # Each lat/long degree is ~69.2 miles
    geo_dist = distance / 69.2

    # Creates boundary limits on the latitude parallel
    lat_plus = lat + geo_dist
    lat_minus = lat - geo_dist

    # Creates boundary limits on the longitude parallel
    long_plus = long + geo_dist
    long_minus = long - geo_dist
    
    long_list = []
    lat_list = []

    # Append to list the longitude coordinates that fall within boundary limits
    for i in df['Longitude']:
        if i < long_plus:
            if i > long_minus:
                long_list.append(i)
    
    # Create new dataframe containing only rows containing longitude's within long_list
    df_long = df.loc[df['Longitude'].isin(long_list)]

    # Append to list the latitude coiordinates that fall within boundary limits
    for i in df_long['Latitude']:
        if i < lat_plus:
            if i > lat_minus:
                lat_list.append(i)
                
    # Create final dataframe containing only rows containing latitude's within lat_list 
    df_final = df_long.loc[df_long['Latitude'].isin(lat_list)]
    
    df_final = df_final.drop('Unnamed: 0', axis=1)
    
    return df_final

# %%
# Function for rest areas using my current lat/long coordinates
df_rest = location_finder(df_rest, 41.840562, -87.659957, 20)
df_rest.head()
# Out:
#      Longitude   Latitude State   Roadway Direction  \
# 526 -87.904665  41.768252    IL     I-294        NB
# 527 -87.908237  41.786779    IL     I-294        SB
# 528 -87.883961  41.947188    IL     I-294        NB
# 529 -87.881632  41.954169    IL     I-294        SB
# 583 -87.596216  41.578319    IL  I-80/294        EB
#
#                                         Name Mile Marker  Restrooms  \
# 526                  TOLLROAD HINSDALE OASIS        MM25       True
# 527                  TOLLROAD HINSDALE OASIS        MM25       True
# 528                    TOLLROAD O'HARE OASIS        MM38       True
# 529                    TOLLROAD O'HARE OASIS        MM38       True
# 583  TOLLWAY CHICAGO SOUTHLAND LINCOLN OASIS         MM1       True
#
#      Restrooms(Vault Toilet)  Restrooms(Portapotties)  Picnic Tables  \
# 526                    False                    False           True
# 527                    False                    False           True
# 528                    False                    False           True
# 529                    False                    False           True
# 583                    False                    False           True
#
#      Vending Machines  Pet Walking Area  Handicapped Facilities  RV Dump  \
# 526             False             False                    True    False
# 527             False             False                    True    False
# 528             False             False                    True    False
# 529             False             False                    True    False
# 583             False             False                    True    False
#
#      Restaurant   Gas  Scenic View
# 526        True  True        False
# 527        True  True        False
# 528        True  True        False
# 529        True  True        False
# 583        True  True        False

# %%
# Test function on walmart dataset
df_walmart = location_finder(df_walmart, 41.840562, -87.659957, 5)

# %%
# Function appears to be working properly
df_walmart
# Out:
#       Longitude   Latitude                   Store Type Store ID     Gas  \
# 1932 -87.689590  41.851869  Walmart Neighborhood Market    #5646  No Gas
# 1936 -87.606931  41.808820  Walmart Neighborhood Market    #3166  No Gas
#
#                        Address     City State Zip Code     Parking  \
# 1932             2551 W Cermak  Chicago    IL    60608  No Parking
# 1936  4720 S Cottage Grove Ave  Chicago    IL    60653  No Parking
#
#         Phone Number
# 1932  (773) 475-4209
# 1936  (773) 420-0081
