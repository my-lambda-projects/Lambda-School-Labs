# %%
import pandas as pd

# %%
df = pd.read_csv('l191.csv')
# Out:
# /usr/local/anaconda3/envs/labs/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df['zipcode'].unique()
# Out:
# array(['20005', '20001', '20020', '20009', '20003', '20019', '20002',
#        '20007', '20010', '20011', '20024', '20012', '20016', '20017',
#        '20008', '20037', '20015', '20036', '20018', nan, '20032', '20712',
#        '20007-3413', '20006', '20910', '20268', '20004', '20815',
#        '20001-4044', '20064', '20372', '20781', '20745', '20912', '20052',
#        ' ', '22202', '20748', '20782', '2939', '20743', 20020.0, 20036.0,
#        20009.0, 20002.0, 20016.0, 20017.0, 20001.0, 20011.0, 20003.0,
#        20019.0, 20007.0, 20910.0, 20008.0, 20010.0, 20012.0, 20024.0,
#        20005.0, 20037.0, 20018.0, 20006.0, 20032.0, 20743.0, 20015.0,
#        20052.0, 20004.0], dtype=object)

# %%
pd.set_option('display.max_columns', 500)

# %%
df['zipcode'].str.split(' ',expand=True)[0]
# Out:
# 0        96815
# 1        96727
# 2        96743
# 3        96704
# 4        96740
#          ...
# 22720    96766
# 22721    96771
# 22722    96740
# 22723    96740
# 22724    96830
# Name: 0, Length: 22725, dtype: object

# %%
df.head(2)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  3002  https://www.airbnb.com/rooms/3002  20190806030454   2019-08-06
# 1  5065  https://www.airbnb.com/rooms/5065  20190806030454   2019-08-06
#
#                                                 name  \
# 0  OCEAN VIEW 1BLK2BEACH,LANAI A/C,FULL KITCH,CEN...
# 1                                           MAUKA BB
#
#                                              summary  \
# 0  ENTIRE PLACE ALONE! -AUG 26- SEPT 3 ,6-8 night...
# 1  Perfect for your vacation, Staycation or just ...
#
#                                                space  \
# 0  **Aloha! I live in a nice, small one bedroom u...
# 1  Mauka B & B is 400 square feet studio with a p...
#
#                                          description experiences_offered  \
# 0  ENTIRE PLACE ALONE! -AUG 26- SEPT 3 ,6-8 night...                none
# 1  Perfect for your vacation, Staycation or just ...                none
#
#                                neighborhood_overview  \
# 0  Waikiki has nice weather 90% percent if the ye...
# 1  Neighbors here are friendly but are not really...
#
#                                                notes  \
# 0                         High security building :-)
# 1  Located near by is Kalopa State Park with 100 ...
#
#                                              transit  \
# 0               Bus right out front goes everywhere.
# 1  There  is a bus stop located in Honoka'a town ...
#
#                                      access  \
# 0  Pool on 4th floor,  laundry in basement.
# 1                  A BBQ grill is available
#
#                                          interaction  \
# 0  Ill see you once in awhile when im home and yo...
# 1                                                NaN
#
#                                          house_rules  thumbnail_url  \
# 0  Only house rules: No shoes on carpet ( ok if y...            NaN
# 1            No smoking indoors and No pets allowed.            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/adf53d15-a...
# 1         NaN  https://a0.muscache.com/im/pictures/36718112/1...
#
#    xl_picture_url  host_id                                host_url host_name  \
# 0             NaN     3364  https://www.airbnb.com/users/show/3364     Lynne
# 1             NaN     7257  https://www.airbnb.com/users/show/7257     Wayne
#
#    host_since                    host_location  \
# 0  2008-09-30  Honolulu, Hawaii, United States
# 1  2009-01-31                           hawaii
#
#                                           host_about  host_response_time  \
# 0  ME--:)I enjoy Socializing, concerts, just chil...  within a few hours
# 1  HI\r\nWE LIVE HERE IN HONOKAA ON \r\nFARM  JUS...  within a few hours
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                80%                   NaN                 f
# 1               100%                   NaN                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/2844d5ce-8...
# 1  https://a0.muscache.com/im/users/7257/profile_...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/2844d5ce-8...            Waikiki
# 1  https://a0.muscache.com/im/users/7257/profile_...      Hamakua Coast
#
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        1.0
# 1                  2.0                        2.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 1  ['email', 'phone', 'reviews', 'offline_governm...                    t
#
#   host_identity_verified                       street  neighbourhood  \
# 0                      t  Honolulu, HI, United States          Oʻahu
# 1                      f   Honokaa, HI, United States  Hamakua Coast
#
#   neighbourhood_cleansed neighbourhood_group_cleansed      city state zipcode  \
# 0   Primary Urban Center                     Honolulu  Honolulu    HI   96815
# 1                Hamakua                       Hawaii   Honokaa    HI   96727
#
#            market smart_location country_code        country  latitude  \
# 0            Oahu   Honolulu, HI           US  United States  21.27603
# 1  The Big Island    Honokaa, HI           US  United States  20.04095
#
#    longitude is_location_exact      property_type        room_type  \
# 0 -157.82210                 t        Condominium     Private room
# 1 -155.43251                 t  Bed and breakfast  Entire home/apt
#
#    accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0             2        1.0       1.0   1.0     Futon
# 1             2        1.0       0.0   1.0  Real Bed
#
#                                            amenities  square_feet   price  \
# 0  {TV,"Cable TV",Internet,"Air conditioning",Poo...          NaN  $69.00
# 1  {"Cable TV",Internet,Wifi,"Free parking on pre...        400.0  $85.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN           NaN              NaN       $45.00                1
# 1          NaN           NaN              NaN          NaN                2
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0       $10.00               1               3                       1
# 1       $50.00               2             700                       2
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       1                       3                       3
# 1                       2                     700                     700
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                     1.0                     3.0       5 days ago
# 1                     2.0                   700.0     3 months ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                3               13               32
# 1                t               25               55               85
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0                32            2019-08-06                232
# 1               358            2019-08-06                 36
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                     21   2010-07-11  2019-07-13                  95.0
# 1                      3   2013-02-18  2019-05-16                  91.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                        9.0                   10.0
# 1                     9.0                        9.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                  9.0
# 1                          9.0                     9.0                  9.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                t     ss#                NaN                f
# 1                t     NaN                NaN                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            2
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               2.10
# 1                                            0               0.46

# %%
df.loc[df['latitude'] == 0]
# Out:
# Empty DataFrame
# Columns: [id, listing_url, scrape_id, last_scraped, name, summary, space, description, experiences_offered, neighborhood_overview, notes, transit, access, interaction, house_rules, thumbnail_url, medium_url, picture_url, xl_picture_url, host_id, host_url, host_name, host_since, host_location, host_about, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_thumbnail_url, host_picture_url, host_neighbourhood, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, street, neighbourhood, neighbourhood_cleansed, neighbourhood_group_cleansed, city, state, zipcode, market, smart_location, country_code, country, latitude, longitude, is_location_exact, property_type, room_type, accommodates, bathrooms, bedrooms, beds, bed_type, amenities, square_feet, price, weekly_price, monthly_price, security_deposit, cleaning_fee, guests_included, extra_people, minimum_nights, maximum_nights, minimum_minimum_nights, maximum_minimum_nights, minimum_maximum_nights, maximum_maximum_nights, minimum_nights_avg_ntm, maximum_nights_avg_ntm, calendar_updated, has_availability, availability_30, availability_60, availability_90, availability_365, calendar_last_scraped, number_of_reviews, number_of_reviews_ltm, first_review, last_review, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, requires_license, license, jurisdiction_names, instant_bookable, is_business_travel_ready, cancellation_policy, require_guest_profile_picture, ...]
# Index: []
